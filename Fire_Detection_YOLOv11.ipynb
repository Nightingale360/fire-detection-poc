# %% [markdown]
# <a href="https://colab.research.google.com/github/Nightingale360/fire-detection-poc/blob/main/Fire_Detection_YOLOv11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics --upgrade -q

# %%
from ultralytics import YOLO
import torch

# %%
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "use CPU")
# Out:
# GPU: NVIDIA A100-SXM4-40GB

# %%
data_path = "/content/drive/MyDrive/Fire_Detection/Fire_and_Smoke_Dataset/data.yaml"

# %%
with open("/content/drive/MyDrive/Fire_Detection/Fire_and_Smoke_Dataset/data.yaml", "w") as f:
    f.write("""
train: /content/drive/MyDrive/Fire_Detection/Fire_and_Smoke_Dataset/train/images
val: /content/drive/MyDrive/Fire_Detection/Fire_and_Smoke_Dataset/valid/images

nc: 1
names: ['fire']
""")

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="/content/drive/MyDrive/Fire_Detection/Fire_and_Smoke_Dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=128,
    project="fire_yolov11",
    name="exp1"
)
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
