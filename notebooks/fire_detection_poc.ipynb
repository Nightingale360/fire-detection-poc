# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
#  32130_week_1_demo-1.ipynb			     Untitled0.ipynb
#  ClearML_Agent_AWS_or_Google_Colab_Notebooks.ipynb   Untitled1.ipynb
#  Data_Exploration.ipynb				     Untitled2.ipynb
#  fire_detection_poc.ipynb			     Untitled3.ipynb
#  preparation.ipynb				     Untitled4.ipynb
#  Task3_5methods.ipynb				     vis.ipynb
#  Task3.ipynb					    'Week5_Data_Exploration_1 (1).ipynb'
#  Task3_modified_with_SVM.ipynb

# %%
# %cd /content
# !git clone https://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@github.com/Nightingale360/fire-detection-poc.git
# Out:
# /content
# Cloning into 'fire-detection-poc'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/fire-detection-poc
# !mkdir -p notebooks
# Out:
# /content/fire-detection-poc
# mkdir: cannot create directory ‘notebooks’: File exists

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/fire_detection_poc.ipynb" /content/fire-detection-poc/notebooks/
# Out:
# cp: failed to access '/content/fire-detection-poc/notebooks/': Not a directory
